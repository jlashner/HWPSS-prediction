# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
L3_file = "../../3LayerSapphire/MF/HWPSS_data/0_deg/Trans.npy"




L5_file = "HWPSS_data/0_deg/Trans.npy"
lables, freqs, A2up, A4up, A2pp, A4pp = np.load(L5_file)
plt.plot(freqs, A2up * 2)

# L5_file = "HWPSS_data/20_deg/Trans.npy"
# lables, freqs, A2up, A4up, A2pp, A4pp = np.load(L5_file)
# plt.plot(freqs, A2up * 2)

lables, freqs, A2up, A4up, A2pp, A4pp = np.load(L3_file)
plt.plot(freqs, A2up * 2)

plt.xlim(125e9, 165e9)
# Out:
# (125000000000.0, 165000000000.0)

# %%
dirnames = ["HWPSS_data2/{}_deg".format(theta) for theta in [0, 20]]

Trans_0deg = np.load(dirnames[0] + "/Trans.npy")
Refl_0deg = np.load(dirnames[0] + "/Refl.npy")
Trans_20deg = np.load(dirnames[1] + "/Trans.npy")
Refl_20deg = np.load(dirnames[1] + "/Refl.npy")

Trans_20
